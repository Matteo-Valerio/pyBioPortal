# %%
from pyBioGate import gene_panels as gp

# %%
df1 = gp.get_all_gene_panels()
df1.head(10)
# Out:
#                                          description  \
# 0  Targeted (27 cancer genes) sequencing of adeno...
# 1                       Targeted panel of 232 genes.
# 2                         Targeted panel of 8 genes.
# 3                 ARCHER-HEME gene panel (199 genes)
# 4                 ARCHER-SOLID Gene Panel (62 genes)
# 5  Targeted sequencing of various tumor types via...
# 6  Targeted sequencing of various tumor types via...
# 7  Targeted sequencing of various tumor types via...
# 8        Targeted panel of 387 cancer-related genes.
# 9   Research (CMO) IMPACT-Heme gene panel version 3.
#
#                    genePanelId
# 0                  ACYC_FMI_27
# 1                      Agilent
# 2                     AmpliSeq
# 3              ARCHER-HEME-CV1
# 4             ARCHER-SOLID-CV1
# 5                      bait_v3
# 6                      bait_v4
# 7                      bait_v5
# 8  bcc_unige_2016_cancer_panel
# 9                  HemePACT_v3

# %%
df2 = gp.get_gene_panel("NSCLC_UNITO_2016_PANEL")
df2.head(10)
# Out:
#                       description             genePanelId  entrezGeneId  \
# 0  Targeted NGS of NSCLC Samples.  NSCLC_UNITO_2016_PANEL            25
# 1  Targeted NGS of NSCLC Samples.  NSCLC_UNITO_2016_PANEL           207
# 2  Targeted NGS of NSCLC Samples.  NSCLC_UNITO_2016_PANEL           324
# 3  Targeted NGS of NSCLC Samples.  NSCLC_UNITO_2016_PANEL           472
# 4  Targeted NGS of NSCLC Samples.  NSCLC_UNITO_2016_PANEL           673
# 5  Targeted NGS of NSCLC Samples.  NSCLC_UNITO_2016_PANEL           999
# 6  Targeted NGS of NSCLC Samples.  NSCLC_UNITO_2016_PANEL          1029
# 7  Targeted NGS of NSCLC Samples.  NSCLC_UNITO_2016_PANEL          1956
# 8  Targeted NGS of NSCLC Samples.  NSCLC_UNITO_2016_PANEL          2064
# 9  Targeted NGS of NSCLC Samples.  NSCLC_UNITO_2016_PANEL          2066
#
#   hugoGeneSymbol
# 0           ABL1
# 1           AKT1
# 2            APC
# 3            ATM
# 4           BRAF
# 5           CDH1
# 6         CDKN2A
# 7           EGFR
# 8          ERBB2
# 9          ERBB4

# %%
df3 = gp.fetch_gene_panels(gene_panel_ids=["NSCLC_UNITO_2016_PANEL", "bcc_unige_2016_cancer_panel"], 
                           projection="DETAILED")
df3
# Out:
#                                      description                  genePanelId  \
# 0    Targeted panel of 387 cancer-related genes.  bcc_unige_2016_cancer_panel
# 1    Targeted panel of 387 cancer-related genes.  bcc_unige_2016_cancer_panel
# 2    Targeted panel of 387 cancer-related genes.  bcc_unige_2016_cancer_panel
# 3    Targeted panel of 387 cancer-related genes.  bcc_unige_2016_cancer_panel
# 4    Targeted panel of 387 cancer-related genes.  bcc_unige_2016_cancer_panel
# ..                                           ...                          ...
# 409               Targeted NGS of NSCLC Samples.       NSCLC_UNITO_2016_PANEL
# 410               Targeted NGS of NSCLC Samples.       NSCLC_UNITO_2016_PANEL
# 411               Targeted NGS of NSCLC Samples.       NSCLC_UNITO_2016_PANEL
# 412               Targeted NGS of NSCLC Samples.       NSCLC_UNITO_2016_PANEL
# 413               Targeted NGS of NSCLC Samples.       NSCLC_UNITO_2016_PANEL
#
#      entrezGeneId hugoGeneSymbol
# 0              25           ABL1
# 1              56          ACRV1
# 2            2181          ACSL3
# 3              91         ACVR1B
# 4              92         ACVR2A
# ..            ...            ...
# 409          4089          SMAD4
# 410          6608            SMO
# 411          6794          STK11
# 412          7157           TP53
# 413          7428            VHL
#
# [414 rows x 4 columns]
