# %%
from pyBioPortal import studies as std

# %%
df1 = std.get_all_studies(keyword="TCGA", projection="DETAILED")
df1
# Out:
#                                                  name  \
# 0      Acute Myeloid Leukemia (TCGA, Firehose Legacy)
# 1            Acute Myeloid Leukemia (TCGA, NEJM 2013)
# 2      Acute Myeloid Leukemia (TCGA, PanCancer Atlas)
# 3    Adrenocortical Carcinoma (TCGA, Firehose Legacy)
# 4    Adrenocortical Carcinoma (TCGA, PanCancer Atlas)
# ..                                                ...
# 86  Uterine Corpus Endometrial Carcinoma (TCGA, Na...
# 87  Uterine Corpus Endometrial Carcinoma (TCGA, Pa...
# 88             Uveal Melanoma (TCGA, Firehose Legacy)
# 89             Uveal Melanoma (TCGA, PanCancer Atlas)
# 90   RAD51B Associated Mixed Cancers (Mandelker 2021)
#
#                                           description  publicStudy  \
# 0   TCGA Acute Myeloid Leukemia. Source data from ...         True
# 1   Whole-genome or whole-exome sequencing analysi...         True
# 2   Acute Myeloid Leukemia TCGA PanCancer data. Th...         True
# 3   TCGA Adrenocortical Carcinoma. Source data fro...         True
# 4   Adrenocortical Carcinoma TCGA PanCancer data. ...         True
# ..                                                ...          ...
# 86  Whole exome sequencing of 373 endometrial carc...         True
# 87  Uterine Corpus Endometrial Carcinoma TCGA PanC...         True
# 88  TCGA Uveal Melanoma. Source data from <A HREF=...         True
# 89  Uveal melanoma TCGA PanCancer data. The origin...         True
# 90  Germline RAD51B loss-of-function variants conf...         True
#
#            groups  status           importDate  allSampleCount  \
# 0          PUBLIC       0  2023-06-19 09:43:19             200
# 1          PUBLIC       0  2023-06-19 23:07:48             200
# 2   PUBLIC;PANCAN       0  2023-06-19 12:05:01             200
# 3          PUBLIC       0  2023-06-19 09:42:47              92
# 4   PUBLIC;PANCAN       0  2023-08-12 08:25:24              92
# ..            ...     ...                  ...             ...
# 86         PUBLIC       0  2023-06-20 17:02:23             373
# 87  PUBLIC;PANCAN       0  2023-08-15 17:17:50             529
# 88         PUBLIC       0  2023-06-19 11:16:24              80
# 89  PUBLIC;PANCAN       0  2023-08-15 21:52:13              80
# 90                      0  2023-06-20 10:33:20              19
#
#     sequencedSampleCount  cnaSampleCount  mrnaRnaSeqSampleCount  ...  \
# 0                    197             191                    179  ...
# 1                    200             191                      0  ...
# 2                    200             191                      0  ...
# 3                     90              90                      0  ...
# 4                     91              89                      0  ...
# ..                   ...             ...                    ...  ...
# 86                   248             363                      0  ...
# 87                   517             523                      0  ...
# 88                    80              80                      0  ...
# 89                    80              80                      0  ...
# 90                    19               0                      0  ...
#
#                          studyId  cancerTypeId           cancerType_name  \
# 0                      laml_tcga           aml    Acute Myeloid Leukemia
# 1                  laml_tcga_pub           aml    Acute Myeloid Leukemia
# 2   laml_tcga_pan_can_atlas_2018           aml    Acute Myeloid Leukemia
# 3                       acc_tcga           acc  Adrenocortical Carcinoma
# 4    acc_tcga_pan_can_atlas_2018           acc  Adrenocortical Carcinoma
# ..                           ...           ...                       ...
# 86                 ucec_tcga_pub          ucec     Endometrial Carcinoma
# 87  ucec_tcga_pan_can_atlas_2018          ucec     Endometrial Carcinoma
# 88                      uvm_tcga            um            Uveal Melanoma
# 89   uvm_tcga_pan_can_atlas_2018            um            Uveal Melanoma
# 90           mixed_msk_tcga_2021         mixed        Mixed Cancer Types
#
#     cancerType_dedicatedColor  cancerType_shortName  cancerType_parent  \
# 0                 LightSalmon                   AML                mnm
# 1                 LightSalmon                   AML                mnm
# 2                 LightSalmon                   AML                mnm
# 3                      Purple                   ACC      adrenal_gland
# 4                      Purple                   ACC      adrenal_gland
# ..                        ...                   ...                ...
# 86                  PeachPuff                  UCEC             uterus
# 87                  PeachPuff                  UCEC             uterus
# 88                      Green                    UM                 om
# 89                      Green                    UM                 om
# 90                      Black                 MIXED              other
#
#     cancerType_cancerTypeId  referenceGenome  \
# 0                       aml             hg19
# 1                       aml             hg19
# 2                       aml             hg19
# 3                       acc             hg19
# 4                       acc             hg19
# ..                      ...              ...
# 86                     ucec             hg19
# 87                     ucec             hg19
# 88                       um             hg19
# 89                       um             hg19
# 90                    mixed             hg19
#
#                                                  pmid           citation
# 0                                                 NaN                NaN
# 1                                            23634996    TCGA, NEJM 2013
# 2   29625048,29596782,29622463,29617662,29625055,2...    TCGA, Cell 2018
# 3                                                 NaN                NaN
# 4   29625048,29596782,29622463,29617662,29625055,2...    TCGA, Cell 2018
# ..                                                ...                ...
# 86                                           23636398  TCGA, Nature 2013
# 87  29625048,29596782,29622463,29617662,29625055,2...    TCGA, Cell 2018
# 88                                                NaN                NaN
# 89  29625048,29596782,29622463,29617662,29625055,2...    TCGA, Cell 2018
# 90                                                NaN                NaN
#
# [91 rows x 29 columns]

# %%
df2 = std.get_study(study_id="brca_tcga")
df2
# Out:
#                                                 name  \
# 0  Breast Invasive Carcinoma (TCGA, Firehose Legacy)
#
#                                          description  publicStudy  groups  \
# 0  TCGA Breast Invasive Carcinoma. Source data fr...         True  PUBLIC
#
#    status           importDate  allSampleCount  sequencedSampleCount  \
# 0       0  2023-11-09 17:45:45            1108                   982
#
#    cnaSampleCount  mrnaRnaSeqSampleCount  ...  readPermission  treatmentCount  \
# 0            1080                      0  ...            True               0
#
#      studyId  cancerTypeId            cancerType_name  \
# 0  brca_tcga          brca  Invasive Breast Carcinoma
#
#    cancerType_dedicatedColor  cancerType_shortName  cancerType_parent  \
# 0                    HotPink                  BRCA             breast
#
#    cancerType_cancerTypeId referenceGenome
# 0                     brca            hg19
#
# [1 rows x 27 columns]

# %%
df3 = std.get_tags_of_study(study_id="bowel_colitis_msk_2022")
df3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df4 = std.fetch_studies(study_ids=["brca_tcga","acc_tcga"], projection="DETAILED")
df4
# Out:
#                                                 name  \
# 0   Adrenocortical Carcinoma (TCGA, Firehose Legacy)
# 1  Breast Invasive Carcinoma (TCGA, Firehose Legacy)
#
#                                          description  publicStudy  groups  \
# 0  TCGA Adrenocortical Carcinoma. Source data fro...         True  PUBLIC
# 1  TCGA Breast Invasive Carcinoma. Source data fr...         True  PUBLIC
#
#    status           importDate  allSampleCount  sequencedSampleCount  \
# 0       0  2023-06-19 09:42:47              92                    90
# 1       0  2023-11-09 17:45:45            1108                   982
#
#    cnaSampleCount  mrnaRnaSeqSampleCount  ...  readPermission  treatmentCount  \
# 0              90                      0  ...            True               0
# 1            1080                      0  ...            True               0
#
#      studyId  cancerTypeId            cancerType_name  \
# 0   acc_tcga           acc   Adrenocortical Carcinoma
# 1  brca_tcga          brca  Invasive Breast Carcinoma
#
#    cancerType_dedicatedColor  cancerType_shortName  cancerType_parent  \
# 0                     Purple                   ACC      adrenal_gland
# 1                    HotPink                  BRCA             breast
#
#    cancerType_cancerTypeId referenceGenome
# 0                      acc            hg19
# 1                     brca            hg19
#
# [2 rows x 27 columns]

# %%
df5 = std.fetch_tags_for_studies(study_ids=["brca_tcga","acc_tcga"])
df5
# Out:
# Response is empty. No data available.
