# %%
from pyBioGate import sample_lists as sl

# %%
df1 = sl.get_all_sample_lists(projection="DETAILED")
df1
# Out:
#                                            category  \
# 0                   all_cases_with_mrna_rnaseq_data
# 1                                all_cases_in_study
# 2                           all_cases_with_cna_data
# 3              all_cases_with_mutation_and_cna_data
# 4     all_cases_with_mutation_and_cna_and_mrna_data
# ...                                             ...
# 2225           all_cases_with_mutation_and_cna_data
# 2226                   all_cases_with_mutation_data
# 2227                         all_cases_with_sv_data
# 2228                             all_cases_in_study
# 2229                   all_cases_with_mutation_data
#
#                                      name  \
# 0     Samples with mRNA data (RNA Seq V2)
# 1                             All samples
# 2                   Samples with CNA data
# 3      Samples with mutation and CNA data
# 4                        Complete samples
# ...                                   ...
# 2225   Samples with mutation and CNA data
# 2226           Samples with mutation data
# 2227                 Samples with SV data
# 2228                          All samples
# 2229           Samples with mutation data
#
#                                             description  sampleCount  \
# 0        Samples with mRNA expression data (79 samples)           79
# 1                              All samples (92 samples)           92
# 2                    Samples with CNA data (90 samples)           90
# 3       Samples with mutation and CNA data (88 samples)           88
# 4     Samples with mutation, CNA and expression data...           75
# ...                                                 ...          ...
# 2225   Samples with mutation and CNA data (322 samples)          322
# 2226           Samples with mutation data (322 samples)          322
# 2227                               Samples with SV data          322
# 2228                           All samples (19 samples)           19
# 2229            Samples with mutation data (19 samples)           19
#
#                                               sampleIds  \
# 0     [TCGA-OR-A5J1-01, TCGA-OR-A5J2-01, TCGA-OR-A5J...
# 1     [TCGA-OR-A5J1-01, TCGA-OR-A5J2-01, TCGA-OR-A5J...
# 2     [TCGA-OR-A5J1-01, TCGA-OR-A5J2-01, TCGA-OR-A5J...
# 3     [TCGA-OR-A5J1-01, TCGA-OR-A5J2-01, TCGA-OR-A5J...
# 4     [TCGA-OR-A5J1-01, TCGA-OR-A5J2-01, TCGA-OR-A5J...
# ...                                                 ...
# 2225  [P-0000463-T01-IM3, P-0000583-T01-IM3, P-00006...
# 2226  [P-0000463-T01-IM3, P-0000583-T01-IM3, P-00006...
# 2227  [P-0000463-T01-IM3, P-0000583-T01-IM3, P-00006...
# 2228  [2-001_Plexiform_Neurofibroma, 2-004_Plexiform...
# 2229  [2-001_Plexiform_Neurofibroma, 2-004_Plexiform...
#
#                        sampleListId              studyId
# 0          acc_tcga_rna_seq_v2_mrna             acc_tcga
# 1                      acc_tcga_all             acc_tcga
# 2                      acc_tcga_cna             acc_tcga
# 3                   acc_tcga_cnaseq             acc_tcga
# 4            acc_tcga_3way_complete             acc_tcga
# ...                             ...                  ...
# 2225     bm_nsclc_mskcc_2023_cnaseq  bm_nsclc_mskcc_2023
# 2226  bm_nsclc_mskcc_2023_sequenced  bm_nsclc_mskcc_2023
# 2227         bm_nsclc_mskcc_2023_sv  bm_nsclc_mskcc_2023
# 2228             nst_nfosi_ntap_all       nst_nfosi_ntap
# 2229       nst_nfosi_ntap_sequenced       nst_nfosi_ntap
#
# [2230 rows x 7 columns]

# %%
df2 = sl.get_sample_list(sample_list_id="brca_tcga_cna")
df2
# Out:
#                   category                   name  \
# 0  all_cases_with_cna_data  Samples with CNA data
#
#                             description  sampleCount  \
# 0  Samples with CNA data (1080 samples)         1080
#
#                                            sampleIds   sampleListId    studyId
# 0  [TCGA-AR-A1AR-01, TCGA-BH-A1EO-01, TCGA-BH-A1E...  brca_tcga_cna  brca_tcga

# %%
df3 = sl.get_all_sample_ids_in_sample_list(sample_list_id="brca_tcga_cna")
df3
# Out:
#                     0
# 0     TCGA-AR-A1AR-01
# 1     TCGA-BH-A1EO-01
# 2     TCGA-BH-A1ES-01
# 3     TCGA-BH-A1ET-01
# 4     TCGA-BH-A1EU-01
# ...               ...
# 1075  TCGA-E2-A1B4-01
# 1076  TCGA-E2-A1B5-01
# 1077  TCGA-E2-A1B6-01
# 1078  TCGA-E2-A1BC-01
# 1079  TCGA-E2-A1BD-01
#
# [1080 rows x 1 columns]

# %%
df4 = sl.fetch_sample_lists(sample_list_ids=["brca_tcga_cna", "brca_tcga_mrna"], projection="DETAILED")
df4
# Out:
#                          category  \
# 0         all_cases_with_cna_data
# 1  all_cases_with_mrna_array_data
#
#                                           name  \
# 0                        Samples with CNA data
# 1  Samples with mRNA data (Agilent microarray)
#
#                                        description  sampleCount  \
# 0             Samples with CNA data (1080 samples)         1080
# 1  Samples with mRNA expression data (529 samples)          529
#
#                                            sampleIds    sampleListId  \
# 0  [TCGA-AR-A1AR-01, TCGA-BH-A1EO-01, TCGA-BH-A1E...   brca_tcga_cna
# 1  [TCGA-AR-A1AR-01, TCGA-BH-A1EO-01, TCGA-BH-A1E...  brca_tcga_mrna
#
#      studyId
# 0  brca_tcga
# 1  brca_tcga

# %%
df5 = sl.get_all_sample_lists_in_study(study_id="brca_tcga",projection="DETAILED")
df5
# Out:
#                                          category  \
# 0                 all_cases_with_mrna_rnaseq_data
# 1                              all_cases_in_study
# 2                         all_cases_with_cna_data
# 3            all_cases_with_mutation_and_cna_data
# 4   all_cases_with_mutation_and_cna_and_mrna_data
# 5                  all_cases_with_mrna_array_data
# 6                 all_cases_with_methylation_data
# 7                 all_cases_with_methylation_data
# 8                 all_cases_with_methylation_data
# 9                                           other
# 10                                          other
# 11                       all_cases_with_rppa_data
# 12                   all_cases_with_mutation_data
#
#                                                  name  \
# 0                 Samples with mRNA data (RNA Seq V2)
# 1                                         All samples
# 2                               Samples with CNA data
# 3                  Samples with mutation and CNA data
# 4                                    Complete samples
# 5         Samples with mRNA data (Agilent microarray)
# 6                       Samples with methylation data
# 7                Samples with methylation data (HM27)
# 8               Samples with methylation data (HM450)
# 9   Samples with phosphoprotein quantification dat...
# 10              Samples with protein data (Mass Spec)
# 11                   Samples with protein data (RPPA)
# 12                         Samples with mutation data
#
#                                           description  sampleCount  \
# 0    Samples with mRNA expression data (1100 samples)         1100
# 1                          All samples (1108 samples)         1108
# 2                Samples with CNA data (1080 samples)         1080
# 3    Samples with mutation and CNA data (963 samples)          963
# 4   Samples with mutation, CNA and expression data...          960
# 5     Samples with mRNA expression data (529 samples)          529
# 6         Samples with methylation data (788 samples)          788
# 7   Samples with methylation data (HM27) (343 samp...          316
# 8   Samples with methylation data (HM450) (885 sam...          788
# 9   Tumor samples with phosphoprotein quantificati...           74
# 10  Samples with protein data (Mass Spec) (74 samp...           74
# 11          Samples protein data (RPPA) (892 samples)          892
# 12           Samples with mutation data (982 samples)          982
#
#                                             sampleIds  \
# 0   [TCGA-AR-A1AR-01, TCGA-BH-A1EO-01, TCGA-BH-A1E...
# 1   [TCGA-AR-A1AR-01, TCGA-BH-A1EO-01, TCGA-BH-A1E...
# 2   [TCGA-AR-A1AR-01, TCGA-BH-A1EO-01, TCGA-BH-A1E...
# 3   [TCGA-AR-A1AR-01, TCGA-BH-A1EO-01, TCGA-BH-A1E...
# 4   [TCGA-AR-A1AR-01, TCGA-BH-A1EO-01, TCGA-BH-A1E...
# 5   [TCGA-AR-A1AR-01, TCGA-BH-A1EO-01, TCGA-BH-A1E...
# 6   [TCGA-AR-A1AR-01, TCGA-BH-A1EO-01, TCGA-BH-A1E...
# 7   [TCGA-A2-A0CX-01, TCGA-A2-A0D0-01, TCGA-A2-A0D...
# 8   [TCGA-AR-A1AR-01, TCGA-BH-A1EO-01, TCGA-BH-A1E...
# 9   [TCGA-A7-A0CE-01, TCGA-A7-A0CJ-01, TCGA-A8-A06...
# 10  [TCGA-A7-A0CE-01, TCGA-A7-A0CJ-01, TCGA-A8-A06...
# 11  [TCGA-BH-A1EO-01, TCGA-BH-A1ES-01, TCGA-BH-A1E...
# 12  [TCGA-AR-A1AR-01, TCGA-BH-A1EO-01, TCGA-BH-A1E...
#
#                                sampleListId    studyId
# 0                 brca_tcga_rna_seq_v2_mrna  brca_tcga
# 1                             brca_tcga_all  brca_tcga
# 2                             brca_tcga_cna  brca_tcga
# 3                          brca_tcga_cnaseq  brca_tcga
# 4                   brca_tcga_3way_complete  brca_tcga
# 5                            brca_tcga_mrna  brca_tcga
# 6                 brca_tcga_methylation_all  brca_tcga
# 7                brca_tcga_methylation_hm27  brca_tcga
# 8               brca_tcga_methylation_hm450  brca_tcga
# 9   brca_tcga_phosphoprotein_quantification  brca_tcga
# 10         brca_tcga_protein_quantification  brca_tcga
# 11                           brca_tcga_rppa  brca_tcga
# 12                      brca_tcga_sequenced  brca_tcga
