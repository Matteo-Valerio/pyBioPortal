# %%
from pyBioPortal import generic_assays as ga

# %%
df1a = ga.fetch_generic_assay_meta(generic_assay_stable_ids=["TULP4_pS563", "TEP1_pS397", "ALAD_214_215_1_1_S215"])
df1a
# Out:
#                 stableId     entityType  \
# 0             TEP1_pS397  GENERIC_ASSAY
# 1            TULP4_pS563  GENERIC_ASSAY
# 2  ALAD_214_215_1_1_S215  GENERIC_ASSAY
#
#   genericEntityMetaProperties_GENE_SYMBOL  \
# 0                                    TEP1
# 1                                   TULP4
# 2                                     NaN
#
#   genericEntityMetaProperties_PHOSPHOSITE  \
# 0                                   pS397
# 1                                   pS563
# 2                                     NaN
#
#   genericEntityMetaProperties_DESCRIPTION genericEntityMetaProperties_NAME
# 0                                     NaN                              NaN
# 1                                     NaN                              NaN
# 2                             NP_000022.3            ALAD S215 214-215 1_1

# %%
df1b = ga.fetch_generic_assay_meta(molecular_profile_ids=["brca_tcga_phosphoprotein_quantification",
                                                          "brain_cptac_2020_phosphoprotein"])
df1b
# Out:
#                          stableId     entityType  \
# 0                     FSCN1_pS328  GENERIC_ASSAY
# 1                     YWHAZ_pS230  GENERIC_ASSAY
# 2                     GMPPB_pS246  GENERIC_ASSAY
# 3                      EPN3_pS503  GENERIC_ASSAY
# 4                  C19orf47_pS395  GENERIC_ASSAY
# ...                           ...            ...
# 76663     DIS3L2_133_154_1_1_S139  GENERIC_ASSAY
# 76664     CRYBG3_442_457_1_1_S457  GENERIC_ASSAY
# 76665  RASAL2_1005_1006_1_1_S1005  GENERIC_ASSAY
# 76666     CAMK2B_338_343_1_1_T342  GENERIC_ASSAY
# 76667      EXOC1_453_458_1_1_S455  GENERIC_ASSAY
#
#       genericEntityMetaProperties_GENE_SYMBOL  \
# 0                                       FSCN1
# 1                                       YWHAZ
# 2                                       GMPPB
# 3                                        EPN3
# 4                                    C19orf47
# ...                                       ...
# 76663                                     NaN
# 76664                                     NaN
# 76665                                     NaN
# 76666                                     NaN
# 76667                                     NaN
#
#       genericEntityMetaProperties_PHOSPHOSITE  \
# 0                                       pS328
# 1                                       pS230
# 2                                       pS246
# 3                                       pS503
# 4                                       pS395
# ...                                       ...
# 76663                                     NaN
# 76664                                     NaN
# 76665                                     NaN
# 76666                                     NaN
# 76667                                     NaN
#
#       genericEntityMetaProperties_DESCRIPTION genericEntityMetaProperties_NAME
# 0                                         NaN                              NaN
# 1                                         NaN                              NaN
# 2                                         NaN                              NaN
# 3                                         NaN                              NaN
# 4                                         NaN                              NaN
# ...                                       ...                              ...
# 76663                             NP_689596.4          DIS3L2 S139 133-154 1_1
# 76664                             NP_705833.3          CRYBG3 S457 442-457 1_1
# 76665                             NP_733793.2       RASAL2 S1005 1005-1006 1_1
# 76666                             NP_742078.1          CAMK2B T342 338-343 1_1
# 76667                             NP_839955.1           EXOC1 S455 453-458 1_1
#
# [76668 rows x 6 columns]

# %%
df2 = ga.get_generic_assay_meta_by_molecular_profile_id("brca_tcga_phosphoprotein_quantification")
df2
# Out:
#                stableId     entityType  \
# 0           FSCN1_pS328  GENERIC_ASSAY
# 1           YWHAZ_pS230  GENERIC_ASSAY
# 2           GMPPB_pS246  GENERIC_ASSAY
# 3            EPN3_pS503  GENERIC_ASSAY
# 4        C19orf47_pS395  GENERIC_ASSAY
# ...                 ...            ...
# 72115    CIC_pS902_S904  GENERIC_ASSAY
# 72116      MAGI1_pT1336  GENERIC_ASSAY
# 72117  PRKD2_pT211_S214  GENERIC_ASSAY
# 72118     PDCD11_pT1012  GENERIC_ASSAY
# 72119        PKN2_pT958  GENERIC_ASSAY
#
#       genericEntityMetaProperties_GENE_SYMBOL  \
# 0                                       FSCN1
# 1                                       YWHAZ
# 2                                       GMPPB
# 3                                        EPN3
# 4                                    C19orf47
# ...                                       ...
# 72115                                     CIC
# 72116                                   MAGI1
# 72117                                   PRKD2
# 72118                                  PDCD11
# 72119                                    PKN2
#
#       genericEntityMetaProperties_PHOSPHOSITE
# 0                                       pS328
# 1                                       pS230
# 2                                       pS246
# 3                                       pS503
# 4                                       pS395
# ...                                       ...
# 72115                              pS902_S904
# 72116                                  pT1336
# 72117                              pT211_S214
# 72118                                  pT1012
# 72119                                   pT958
#
# [72120 rows x 4 columns]

# %%
df3 = ga.get_generic_assay_meta_by_id("TULP4_pS563")
df3
# Out:
#       stableId     entityType genericEntityMetaProperties_GENE_SYMBOL  \
# 0  TULP4_pS563  GENERIC_ASSAY                                   TULP4
#
#   genericEntityMetaProperties_PHOSPHOSITE
# 0                                   pS563
