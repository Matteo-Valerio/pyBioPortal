# %%
from pyBioGate import molecular_profiles as mf

# %%
df1 = mf.get_all_molecular_profiles()
df1.head(5)
# Out:
#   molecularAlterationType    datatype  \
# 0           PROTEIN_LEVEL  LOG2-VALUE
# 1           PROTEIN_LEVEL     Z-SCORE
# 2  COPY_NUMBER_ALTERATION    DISCRETE
# 3  COPY_NUMBER_ALTERATION  CONTINUOUS
# 4       MUTATION_EXTENDED         MAF
#
#                                            name  \
# 0                     Protein expression (RPPA)
# 1            Protein expression z-scores (RPPA)
# 2  Putative copy-number alterations from GISTIC
# 3     Capped relative linear copy-number values
# 4                                     Mutations
#
#                                          description  \
# 0  Protein expression measured by reverse-phase p...
# 1  Protein expression, measured by reverse-phase ...
# 2  Putative copy-number calls on 90 cases determi...
# 3  Capped relative linear copy-number values for ...
# 4  Mutation data from whole exome sequencing. Mut...
#
#    showProfileInAnalysisTab  patientLevel     molecularProfileId   studyId  \
# 0                     False         False          acc_tcga_rppa  acc_tcga
# 1                      True         False  acc_tcga_rppa_Zscores  acc_tcga
# 2                      True         False        acc_tcga_gistic  acc_tcga
# 3                     False         False    acc_tcga_linear_CNA  acc_tcga
# 4                      True         False     acc_tcga_mutations  acc_tcga
#
#   genericAssayType  pivotThreshold sortOrder
# 0              NaN             NaN       NaN
# 1              NaN             NaN       NaN
# 2              NaN             NaN       NaN
# 3              NaN             NaN       NaN
# 4              NaN             NaN       NaN

# %%
df2 = mf.get_molecular_profile("gbm_tcga_pan_can_atlas_2018_armlevel_cna")
df2
# Out:
#   molecularAlterationType genericAssayType     datatype  \
# 0           GENERIC_ASSAY     ARMLEVEL_CNA  CATEGORICAL
#
#                                          name  \
# 0  Putative arm-level copy-number from GISTIC
#
#                                        description  showProfileInAnalysisTab  \
# 0  Putative arm-level copy-number from GISTIC 2.0.                      True
#
#    patientLevel                        molecularProfileId  \
# 0         False  gbm_tcga_pan_can_atlas_2018_armlevel_cna
#
#                        studyId  \
# 0  gbm_tcga_pan_can_atlas_2018
#
#                                         study_name  ... study_publicStudy  \
# 0  Glioblastoma Multiforme (TCGA, PanCancer Atlas)  ...              True
#
#                                           study_pmid   study_citation  \
# 0  29625048,29596782,29622463,29617662,29625055,2...  TCGA, Cell 2018
#
#     study_groups study_status     study_importDate study_readPermission  \
# 0  PUBLIC;PANCAN            0  2023-08-14 08:28:47                 True
#
#                  study_studyId study_cancerTypeId study_referenceGenome
# 0  gbm_tcga_pan_can_atlas_2018                gbm                  hg19
#
# [1 rows x 21 columns]

# %%
df3a = mf.fetch_molecular_profiles(molecular_profile_ids=["brca_tcga_mrna", "acc_tcga_rna_seq_v2_mrna"])
df3a
# Out:
#   molecularAlterationType    datatype                               name  \
# 0         MRNA_EXPRESSION  CONTINUOUS  mRNA expression (RNA Seq V2 RSEM)
# 1         MRNA_EXPRESSION  CONTINUOUS       mRNA expression (microarray)
#
#                                          description  \
# 0             mRNA gene expression (RNA Seq V2 RSEM)
# 1  Expression levels for 17155 genes in 590 brca ...
#
#    showProfileInAnalysisTab  patientLevel        molecularProfileId    studyId
# 0                     False         False  acc_tcga_rna_seq_v2_mrna   acc_tcga
# 1                     False         False            brca_tcga_mrna  brca_tcga

# %%
df3b = mf.fetch_molecular_profiles(study_ids=["brca_tcga", "acc_tcga"])
df3b.head(5)
# Out:
#   molecularAlterationType    datatype  \
# 0           PROTEIN_LEVEL  LOG2-VALUE
# 1           PROTEIN_LEVEL     Z-SCORE
# 2  COPY_NUMBER_ALTERATION    DISCRETE
# 3  COPY_NUMBER_ALTERATION  CONTINUOUS
# 4       MUTATION_EXTENDED         MAF
#
#                                            name  \
# 0                     Protein expression (RPPA)
# 1            Protein expression z-scores (RPPA)
# 2  Putative copy-number alterations from GISTIC
# 3     Capped relative linear copy-number values
# 4                                     Mutations
#
#                                          description  \
# 0  Protein expression measured by reverse-phase p...
# 1  Protein expression, measured by reverse-phase ...
# 2  Putative copy-number calls on 90 cases determi...
# 3  Capped relative linear copy-number values for ...
# 4  Mutation data from whole exome sequencing. Mut...
#
#    showProfileInAnalysisTab  patientLevel     molecularProfileId   studyId  \
# 0                     False         False          acc_tcga_rppa  acc_tcga
# 1                      True         False  acc_tcga_rppa_Zscores  acc_tcga
# 2                      True         False        acc_tcga_gistic  acc_tcga
# 3                     False         False    acc_tcga_linear_CNA  acc_tcga
# 4                      True         False     acc_tcga_mutations  acc_tcga
#
#   genericAssayType  pivotThreshold sortOrder
# 0              NaN             NaN       NaN
# 1              NaN             NaN       NaN
# 2              NaN             NaN       NaN
# 3              NaN             NaN       NaN
# 4              NaN             NaN       NaN

# %%
df4 = mf.get_all_molecular_profiles_in_study(study_id="brca_tcga", sortBy="description")
df4.head(5)
# Out:
#   molecularAlterationType    datatype  \
# 0  COPY_NUMBER_ALTERATION  CONTINUOUS
# 1         MRNA_EXPRESSION  CONTINUOUS
# 2         MRNA_EXPRESSION     Z-SCORE
# 3         MRNA_EXPRESSION     Z-SCORE
# 4             METHYLATION  CONTINUOUS
#
#                                                 name  \
# 0          Capped relative linear copy-number values
# 1                       mRNA expression (microarray)
# 2  mRNA expression z-scores relative to all sampl...
# 3  mRNA expression z-scores relative to all sampl...
# 4                                Methylation (HM450)
#
#                                          description  \
# 0  Capped relative linear copy-number values for ...
# 1  Expression levels for 17155 genes in 590 brca ...
# 2  Log-transformed mRNA expression z-scores compa...
# 3  Log-transformed mRNA expression z-scores compa...
# 4  Methylation (HM450) beta-values for genes in 8...
#
#    showProfileInAnalysisTab  patientLevel  \
# 0                     False         False
# 1                     False         False
# 2                      True         False
# 3                      True         False
# 4                     False         False
#
#                                   molecularProfileId    studyId  \
# 0                               brca_tcga_linear_CNA  brca_tcga
# 1                                     brca_tcga_mrna  brca_tcga
# 2           brca_tcga_mrna_median_all_sample_Zscores  brca_tcga
# 3  brca_tcga_rna_seq_v2_mrna_median_all_sample_Zs...  brca_tcga
# 4                        brca_tcga_methylation_hm450  brca_tcga
#
#   genericAssayType  pivotThreshold sortOrder
# 0              NaN             NaN       NaN
# 1              NaN             NaN       NaN
# 2              NaN             NaN       NaN
# 3              NaN             NaN       NaN
# 4              NaN             NaN       NaN
