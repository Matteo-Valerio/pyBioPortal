# %%
from pybioportal import mutations as mts

# %%
df1 = mts.get_muts_in_mol_prof_by_sample_list_id(molecular_profile_id="brca_tcga_mutations", 
                                                 sample_list_id="brca_tcga_all", 
                                                 entrez_gene_id="672")
df1
# Out:
#                        uniqueSampleKey                uniquePatientKey  \
# 0   VENHQS1BMi1BNFMwLTAxOmJyY2FfdGNnYQ  VENHQS1BMi1BNFMwOmJyY2FfdGNnYQ
# 1   VENHQS1FMi1BMUw5LTAxOmJyY2FfdGNnYQ  VENHQS1FMi1BMUw5OmJyY2FfdGNnYQ
# 2   VENHQS1CSC1BMFdBLTAxOmJyY2FfdGNnYQ  VENHQS1CSC1BMFdBOmJyY2FfdGNnYQ
# 3   VENHQS1FOS1BMU5DLTAxOmJyY2FfdGNnYQ  VENHQS1FOS1BMU5DOmJyY2FfdGNnYQ
# 4   VENHQS1DOC1BMTJULTAxOmJyY2FfdGNnYQ  VENHQS1DOC1BMTJUOmJyY2FfdGNnYQ
# 5   VENHQS1MTC1BNVlQLTAxOmJyY2FfdGNnYQ  VENHQS1MTC1BNVlQOmJyY2FfdGNnYQ
# 6   VENHQS1BTy1BMUtSLTAxOmJyY2FfdGNnYQ  VENHQS1BTy1BMUtSOmJyY2FfdGNnYQ
# 7   VENHQS1BMS1BMFNJLTAxOmJyY2FfdGNnYQ  VENHQS1BMS1BMFNJOmJyY2FfdGNnYQ
# 8   VENHQS1BTi1BMFhVLTAxOmJyY2FfdGNnYQ  VENHQS1BTi1BMFhVOmJyY2FfdGNnYQ
# 9   VENHQS1BMi1BMjVCLTAxOmJyY2FfdGNnYQ  VENHQS1BMi1BMjVCOmJyY2FfdGNnYQ
# 10  VENHQS1FVy1BMkZSLTAxOmJyY2FfdGNnYQ  VENHQS1FVy1BMkZSOmJyY2FfdGNnYQ
# 11  VENHQS1EOC1BMjdNLTAxOmJyY2FfdGNnYQ  VENHQS1EOC1BMjdNOmJyY2FfdGNnYQ
# 12  VENHQS1QRS1BNURFLTAxOmJyY2FfdGNnYQ  VENHQS1QRS1BNURFOmJyY2FfdGNnYQ
#
#      molecularProfileId         sampleId     patientId  entrezGeneId  \
# 0   brca_tcga_mutations  TCGA-A2-A4S0-01  TCGA-A2-A4S0           672
# 1   brca_tcga_mutations  TCGA-E2-A1L9-01  TCGA-E2-A1L9           672
# 2   brca_tcga_mutations  TCGA-BH-A0WA-01  TCGA-BH-A0WA           672
# 3   brca_tcga_mutations  TCGA-E9-A1NC-01  TCGA-E9-A1NC           672
# 4   brca_tcga_mutations  TCGA-C8-A12T-01  TCGA-C8-A12T           672
# 5   brca_tcga_mutations  TCGA-LL-A5YP-01  TCGA-LL-A5YP           672
# 6   brca_tcga_mutations  TCGA-AO-A1KR-01  TCGA-AO-A1KR           672
# 7   brca_tcga_mutations  TCGA-A1-A0SI-01  TCGA-A1-A0SI           672
# 8   brca_tcga_mutations  TCGA-AN-A0XU-01  TCGA-AN-A0XU           672
# 9   brca_tcga_mutations  TCGA-A2-A25B-01  TCGA-A2-A25B           672
# 10  brca_tcga_mutations  TCGA-EW-A2FR-01  TCGA-EW-A2FR           672
# 11  brca_tcga_mutations  TCGA-D8-A27M-01  TCGA-D8-A27M           672
# 12  brca_tcga_mutations  TCGA-PE-A5DE-01  TCGA-PE-A5DE           672
#
#       studyId            center mutationStatus validationStatus  ...  \
# 0   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 1   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 2   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 3   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 4   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 5   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 6   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 7   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 8   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 9   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 10  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 11  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 12  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
#
#     proteinChange       mutationType  ncbiBuild  variantType  \
# 0            K50T  Missense_Mutation     GRCh37          SNP
# 1          S1027I  Missense_Mutation     GRCh37          SNP
# 2    X1559_splice        Splice_Site     GRCh37          SNP
# 3           Q139*  Nonsense_Mutation     GRCh37          SNP
# 4          D1344H  Missense_Mutation     GRCh37          SNP
# 5            D96H  Missense_Mutation     GRCh37          SNP
# 6         C644del       In_Frame_Del     GRCh37          DEL
# 7             E9Q  Missense_Mutation     GRCh37          SNP
# 8          G1788V  Missense_Mutation     GRCh37          SNP
# 9           E720*  Nonsense_Mutation     GRCh37          SNP
# 10          D366N  Missense_Mutation     GRCh37          SNP
# 11    P1614Qfs*19    Frame_Shift_Del     GRCh37          DEL
# 12         E1419K  Missense_Mutation     GRCh37          SNP
#
#                    keyword chr variantAllele refseqMrnaId proteinPosStart  \
# 0       BRCA1 K50 missense  17             G  NM_007294.3              50
# 1     BRCA1 S1027 missense  17             A  NM_007294.3            1027
# 2         BRCA1 truncating  17             T  NM_007294.3            1559
# 3         BRCA1 truncating  17             A  NM_007294.3             139
# 4     BRCA1 D1344 missense  17             G  NM_007294.3            1344
# 5       BRCA1 D96 missense  17             G  NM_007294.3              96
# 6   BRCA1 644-644 deletion  17             -  NM_007294.3             644
# 7        BRCA1 E9 missense  17             G  NM_007294.3               9
# 8     BRCA1 G1788 missense  17             A  NM_007294.3            1788
# 9         BRCA1 truncating  17             A  NM_007294.3             720
# 10     BRCA1 D366 missense  17             T  NM_007294.3             366
# 11        BRCA1 truncating  17             -  NM_007294.3            1614
# 12    BRCA1 E1419 missense  17             T  NM_007294.3            1419
#
#    proteinPosEnd
# 0             50
# 1           1027
# 2           1559
# 3            139
# 4           1344
# 5             96
# 6            644
# 7              9
# 8           1788
# 9            720
# 10           366
# 11          1614
# 12          1419
#
# [13 rows x 25 columns]

# %%
df2a = mts.fetch_muts_in_mol_prof(molecular_profile_id="brca_tcga_mutations",
                                  entrez_gene_ids=["1005", "1020"],
                                  sample_ids = ["TCGA-AR-A1AR-01","TCGA-BH-A1EO-01"])                                                 
df2a
# Out:
#                       uniqueSampleKey                uniquePatientKey  \
# 0  VENHQS1CSC1BMUVPLTAxOmJyY2FfdGNnYQ  VENHQS1CSC1BMUVPOmJyY2FfdGNnYQ
# 1  VENHQS1CSC1BMUVPLTAxOmJyY2FfdGNnYQ  VENHQS1CSC1BMUVPOmJyY2FfdGNnYQ
#
#     molecularProfileId         sampleId     patientId  entrezGeneId  \
# 0  brca_tcga_mutations  TCGA-BH-A1EO-01  TCGA-BH-A1EO          1005
# 1  brca_tcga_mutations  TCGA-BH-A1EO-01  TCGA-BH-A1EO          1020
#
#      studyId            center mutationStatus validationStatus  ...  \
# 0  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 1  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
#
#    proteinChange       mutationType  ncbiBuild  variantType  \
# 0          R695Q  Missense_Mutation     GRCh37          SNP
# 1          V162L  Missense_Mutation     GRCh37          SNP
#
#               keyword chr variantAllele refseqMrnaId proteinPosStart  \
# 0  CDH7 R695 missense  18             A  NM_004361.2             695
# 1  CDK5 V162 missense   7             A  NM_004935.3             162
#
#   proteinPosEnd
# 0           695
# 1           162
#
# [2 rows x 25 columns]

# %%
df2b = mts.fetch_muts_in_mol_prof(molecular_profile_id="brca_tcga_mutations", 
                                  entrez_gene_ids=["1005", "1020"],
                                  sample_list_id="brca_tcga_all")
df2b
# Out:
#                       uniqueSampleKey                uniquePatientKey  \
# 0  VENHQS1CSC1BMUVPLTAxOmJyY2FfdGNnYQ  VENHQS1CSC1BMUVPOmJyY2FfdGNnYQ
# 1  VENHQS1PTC1BNUQ4LTAxOmJyY2FfdGNnYQ  VENHQS1PTC1BNUQ4OmJyY2FfdGNnYQ
# 2  VENHQS1EOC1BMUpMLTAxOmJyY2FfdGNnYQ  VENHQS1EOC1BMUpMOmJyY2FfdGNnYQ
# 3  VENHQS1BTi1BMDQ2LTAxOmJyY2FfdGNnYQ  VENHQS1BTi1BMDQ2OmJyY2FfdGNnYQ
# 4  VENHQS1BTi1BMDQ2LTAxOmJyY2FfdGNnYQ  VENHQS1BTi1BMDQ2OmJyY2FfdGNnYQ
# 5  VENHQS1CSC1BMUVPLTAxOmJyY2FfdGNnYQ  VENHQS1CSC1BMUVPOmJyY2FfdGNnYQ
# 6  VENHQS1EOC1BMUpBLTAxOmJyY2FfdGNnYQ  VENHQS1EOC1BMUpBOmJyY2FfdGNnYQ
#
#     molecularProfileId         sampleId     patientId  entrezGeneId  \
# 0  brca_tcga_mutations  TCGA-BH-A1EO-01  TCGA-BH-A1EO          1005
# 1  brca_tcga_mutations  TCGA-OL-A5D8-01  TCGA-OL-A5D8          1005
# 2  brca_tcga_mutations  TCGA-D8-A1JL-01  TCGA-D8-A1JL          1005
# 3  brca_tcga_mutations  TCGA-AN-A046-01  TCGA-AN-A046          1005
# 4  brca_tcga_mutations  TCGA-AN-A046-01  TCGA-AN-A046          1005
# 5  brca_tcga_mutations  TCGA-BH-A1EO-01  TCGA-BH-A1EO          1020
# 6  brca_tcga_mutations  TCGA-D8-A1JA-01  TCGA-D8-A1JA          1020
#
#      studyId            center mutationStatus validationStatus  ...  \
# 0  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 1  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 2  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 3  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 4  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 5  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 6  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
#
#    proteinChange       mutationType  ncbiBuild  variantType  \
# 0          R695Q  Missense_Mutation     GRCh37          SNP
# 1          S556*  Nonsense_Mutation     GRCh37          SNP
# 2           G78A  Missense_Mutation     GRCh37          SNP
# 3          T178M  Missense_Mutation     GRCh37          SNP
# 4          R264Q  Missense_Mutation     GRCh37          SNP
# 5          V162L  Missense_Mutation     GRCh37          SNP
# 6          E101Q  Missense_Mutation     GRCh37          SNP
#
#               keyword chr variantAllele refseqMrnaId proteinPosStart  \
# 0  CDH7 R695 missense  18             A  NM_004361.2             695
# 1     CDH7 truncating  18             A  NM_004361.2             556
# 2   CDH7 G78 missense  18             C  NM_004361.2              78
# 3  CDH7 T178 missense  18             T  NM_004361.2             178
# 4  CDH7 R264 missense  18             A  NM_004361.2             264
# 5  CDK5 V162 missense   7             A  NM_004935.3             162
# 6  CDK5 E101 missense   7             G  NM_004935.3             101
#
#   proteinPosEnd
# 0           695
# 1           556
# 2            78
# 3           178
# 4           264
# 5           162
# 6           101
#
# [7 rows x 25 columns]

# %%
df3a = mts.fetch_muts_in_multiple_mol_profs(entrez_gene_ids=["672","675"], 
                                            molecular_profile_ids=["brca_tcga_mutations", "acc_tcga_mutations"])
df3a
# Out:
#                        uniqueSampleKey                uniquePatientKey  \
# 0     VENHQS1PUi1BNUxFLTAxOmFjY190Y2dh    VENHQS1PUi1BNUxFOmFjY190Y2dh
# 1   VENHQS1BMi1BNFMwLTAxOmJyY2FfdGNnYQ  VENHQS1BMi1BNFMwOmJyY2FfdGNnYQ
# 2   VENHQS1FMi1BMUw5LTAxOmJyY2FfdGNnYQ  VENHQS1FMi1BMUw5OmJyY2FfdGNnYQ
# 3   VENHQS1CSC1BMFdBLTAxOmJyY2FfdGNnYQ  VENHQS1CSC1BMFdBOmJyY2FfdGNnYQ
# 4   VENHQS1FOS1BMU5DLTAxOmJyY2FfdGNnYQ  VENHQS1FOS1BMU5DOmJyY2FfdGNnYQ
# 5   VENHQS1DOC1BMTJULTAxOmJyY2FfdGNnYQ  VENHQS1DOC1BMTJUOmJyY2FfdGNnYQ
# 6   VENHQS1MTC1BNVlQLTAxOmJyY2FfdGNnYQ  VENHQS1MTC1BNVlQOmJyY2FfdGNnYQ
# 7   VENHQS1BTy1BMUtSLTAxOmJyY2FfdGNnYQ  VENHQS1BTy1BMUtSOmJyY2FfdGNnYQ
# 8   VENHQS1BMS1BMFNJLTAxOmJyY2FfdGNnYQ  VENHQS1BMS1BMFNJOmJyY2FfdGNnYQ
# 9   VENHQS1BTi1BMFhVLTAxOmJyY2FfdGNnYQ  VENHQS1BTi1BMFhVOmJyY2FfdGNnYQ
# 10  VENHQS1BMi1BMjVCLTAxOmJyY2FfdGNnYQ  VENHQS1BMi1BMjVCOmJyY2FfdGNnYQ
# 11  VENHQS1FVy1BMkZSLTAxOmJyY2FfdGNnYQ  VENHQS1FVy1BMkZSOmJyY2FfdGNnYQ
# 12  VENHQS1EOC1BMjdNLTAxOmJyY2FfdGNnYQ  VENHQS1EOC1BMjdNOmJyY2FfdGNnYQ
# 13  VENHQS1QRS1BNURFLTAxOmJyY2FfdGNnYQ  VENHQS1QRS1BNURFOmJyY2FfdGNnYQ
# 14  VENHQS1BOC1BMDdJLTAxOmJyY2FfdGNnYQ  VENHQS1BOC1BMDdJOmJyY2FfdGNnYQ
# 15  VENHQS1EOC1BMUpQLTAxOmJyY2FfdGNnYQ  VENHQS1EOC1BMUpQOmJyY2FfdGNnYQ
# 16  VENHQS1BOC1BMDhMLTAxOmJyY2FfdGNnYQ  VENHQS1BOC1BMDhMOmJyY2FfdGNnYQ
# 17  VENHQS1EOC1BMjdHLTAxOmJyY2FfdGNnYQ  VENHQS1EOC1BMjdHOmJyY2FfdGNnYQ
# 18  VENHQS1BTi1BMEFULTAxOmJyY2FfdGNnYQ  VENHQS1BTi1BMEFUOmJyY2FfdGNnYQ
# 19  VENHQS1BMi1BMFQwLTAxOmJyY2FfdGNnYQ  VENHQS1BMi1BMFQwOmJyY2FfdGNnYQ
# 20  VENHQS1DOC1BMTJULTAxOmJyY2FfdGNnYQ  VENHQS1DOC1BMTJUOmJyY2FfdGNnYQ
# 21  VENHQS1BOC1BMDhCLTAxOmJyY2FfdGNnYQ  VENHQS1BOC1BMDhCOmJyY2FfdGNnYQ
# 22  VENHQS1BUi1BMUFJLTAxOmJyY2FfdGNnYQ  VENHQS1BUi1BMUFJOmJyY2FfdGNnYQ
# 23  VENHQS1CSC1BMEhGLTAxOmJyY2FfdGNnYQ  VENHQS1CSC1BMEhGOmJyY2FfdGNnYQ
# 24  VENHQS1BQy1BMjNILTAxOmJyY2FfdGNnYQ  VENHQS1BQy1BMjNIOmJyY2FfdGNnYQ
# 25  VENHQS1BQy1BMjNILTAxOmJyY2FfdGNnYQ  VENHQS1BQy1BMjNIOmJyY2FfdGNnYQ
# 26  VENHQS1FVy1BMVBFLTAxOmJyY2FfdGNnYQ  VENHQS1FVy1BMVBFOmJyY2FfdGNnYQ
# 27  VENHQS1FVy1BMVBFLTAxOmJyY2FfdGNnYQ  VENHQS1FVy1BMVBFOmJyY2FfdGNnYQ
# 28  VENHQS1BMi1BMjVGLTAxOmJyY2FfdGNnYQ  VENHQS1BMi1BMjVGOmJyY2FfdGNnYQ
# 29  VENHQS1BTy1BMTI0LTAxOmJyY2FfdGNnYQ  VENHQS1BTy1BMTI0OmJyY2FfdGNnYQ
# 30  VENHQS1BTi1BMDQ2LTAxOmJyY2FfdGNnYQ  VENHQS1BTi1BMDQ2OmJyY2FfdGNnYQ
#
#      molecularProfileId         sampleId     patientId  entrezGeneId  \
# 0    acc_tcga_mutations  TCGA-OR-A5LE-01  TCGA-OR-A5LE           675
# 1   brca_tcga_mutations  TCGA-A2-A4S0-01  TCGA-A2-A4S0           672
# 2   brca_tcga_mutations  TCGA-E2-A1L9-01  TCGA-E2-A1L9           672
# 3   brca_tcga_mutations  TCGA-BH-A0WA-01  TCGA-BH-A0WA           672
# 4   brca_tcga_mutations  TCGA-E9-A1NC-01  TCGA-E9-A1NC           672
# 5   brca_tcga_mutations  TCGA-C8-A12T-01  TCGA-C8-A12T           672
# 6   brca_tcga_mutations  TCGA-LL-A5YP-01  TCGA-LL-A5YP           672
# 7   brca_tcga_mutations  TCGA-AO-A1KR-01  TCGA-AO-A1KR           672
# 8   brca_tcga_mutations  TCGA-A1-A0SI-01  TCGA-A1-A0SI           672
# 9   brca_tcga_mutations  TCGA-AN-A0XU-01  TCGA-AN-A0XU           672
# 10  brca_tcga_mutations  TCGA-A2-A25B-01  TCGA-A2-A25B           672
# 11  brca_tcga_mutations  TCGA-EW-A2FR-01  TCGA-EW-A2FR           672
# 12  brca_tcga_mutations  TCGA-D8-A27M-01  TCGA-D8-A27M           672
# 13  brca_tcga_mutations  TCGA-PE-A5DE-01  TCGA-PE-A5DE           672
# 14  brca_tcga_mutations  TCGA-A8-A07I-01  TCGA-A8-A07I           675
# 15  brca_tcga_mutations  TCGA-D8-A1JP-01  TCGA-D8-A1JP           675
# 16  brca_tcga_mutations  TCGA-A8-A08L-01  TCGA-A8-A08L           675
# 17  brca_tcga_mutations  TCGA-D8-A27G-01  TCGA-D8-A27G           675
# 18  brca_tcga_mutations  TCGA-AN-A0AT-01  TCGA-AN-A0AT           675
# 19  brca_tcga_mutations  TCGA-A2-A0T0-01  TCGA-A2-A0T0           675
# 20  brca_tcga_mutations  TCGA-C8-A12T-01  TCGA-C8-A12T           675
# 21  brca_tcga_mutations  TCGA-A8-A08B-01  TCGA-A8-A08B           675
# 22  brca_tcga_mutations  TCGA-AR-A1AI-01  TCGA-AR-A1AI           675
# 23  brca_tcga_mutations  TCGA-BH-A0HF-01  TCGA-BH-A0HF           675
# 24  brca_tcga_mutations  TCGA-AC-A23H-01  TCGA-AC-A23H           675
# 25  brca_tcga_mutations  TCGA-AC-A23H-01  TCGA-AC-A23H           675
# 26  brca_tcga_mutations  TCGA-EW-A1PE-01  TCGA-EW-A1PE           675
# 27  brca_tcga_mutations  TCGA-EW-A1PE-01  TCGA-EW-A1PE           675
# 28  brca_tcga_mutations  TCGA-A2-A25F-01  TCGA-A2-A25F           675
# 29  brca_tcga_mutations  TCGA-AO-A124-01  TCGA-AO-A124           675
# 30  brca_tcga_mutations  TCGA-AN-A046-01  TCGA-AN-A046           675
#
#       studyId            center mutationStatus validationStatus  ...  \
# 0    acc_tcga          bcgsc.ca        Somatic         Untested  ...
# 1   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 2   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 3   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 4   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 5   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 6   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 7   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 8   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 9   brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 10  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 11  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 12  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 13  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 14  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 15  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 16  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 17  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 18  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 19  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 20  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 21  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 22  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 23  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 24  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 25  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 26  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 27  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 28  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 29  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 30  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
#
#       proteinChange       mutationType  ncbiBuild  variantType  chr  \
# 0   V733_L734insFFF       In_Frame_Ins     GRCh37          INS   13
# 1              K50T  Missense_Mutation     GRCh37          SNP   17
# 2            S1027I  Missense_Mutation     GRCh37          SNP   17
# 3      X1559_splice        Splice_Site     GRCh37          SNP   17
# 4             Q139*  Nonsense_Mutation     GRCh37          SNP   17
# 5            D1344H  Missense_Mutation     GRCh37          SNP   17
# 6              D96H  Missense_Mutation     GRCh37          SNP   17
# 7           C644del       In_Frame_Del     GRCh37          DEL   17
# 8               E9Q  Missense_Mutation     GRCh37          SNP   17
# 9            G1788V  Missense_Mutation     GRCh37          SNP   17
# 10            E720*  Nonsense_Mutation     GRCh37          SNP   17
# 11            D366N  Missense_Mutation     GRCh37          SNP   17
# 12      P1614Qfs*19    Frame_Shift_Del     GRCh37          DEL   17
# 13           E1419K  Missense_Mutation     GRCh37          SNP   17
# 14           D1355Y  Missense_Mutation     GRCh37          SNP   13
# 15      L1965Ffs*39    Frame_Shift_Del     GRCh37          DEL   13
# 16     X2602_splice        Splice_Site     GRCh37          SNP   13
# 17           E2175Q  Missense_Mutation     GRCh37          SNP   13
# 18           E2650Q  Missense_Mutation     GRCh37          SNP   13
# 19           L2926*  Nonsense_Mutation     GRCh37          SNP   13
# 20           E3177Q  Missense_Mutation     GRCh37          SNP   13
# 21         V1270del       In_Frame_Del     GRCh37          DEL   13
# 22           R2336C  Missense_Mutation     GRCh37          SNP   13
# 23            S879F  Missense_Mutation     GRCh37          SNP   13
# 24            D687H  Missense_Mutation     GRCh37          SNP   13
# 25           D1033H  Missense_Mutation     GRCh37          SNP   13
# 26           E1158Q  Missense_Mutation     GRCh37          SNP   13
# 27           K1191N  Missense_Mutation     GRCh37          SNP   13
# 28           Y3049S  Missense_Mutation     GRCh37          SNP   13
# 29           C3304S  Missense_Mutation     GRCh37          SNP   13
# 30           E3342K  Missense_Mutation     GRCh37          SNP   13
#
#     variantAllele refseqMrnaId proteinPosStart proteinPosEnd  \
# 0       TCTTCTTCT           NA             733           734
# 1               G  NM_007294.3              50            50
# 2               A  NM_007294.3            1027          1027
# 3               T  NM_007294.3            1559          1559
# 4               A  NM_007294.3             139           139
# 5               G  NM_007294.3            1344          1344
# 6               G  NM_007294.3              96            96
# 7               -  NM_007294.3             644           644
# 8               G  NM_007294.3               9             9
# 9               A  NM_007294.3            1788          1788
# 10              A  NM_007294.3             720           720
# 11              T  NM_007294.3             366           366
# 12              -  NM_007294.3            1614          1614
# 13              T  NM_007294.3            1419          1419
# 14              T           NA            1355          1355
# 15              -           NA            1965          1965
# 16              A           NA            2602          2602
# 17              C           NA            2175          2175
# 18              C           NA            2650          2650
# 19              G           NA            2926          2926
# 20              C           NA            3177          3177
# 21              -           NA            1268          1270
# 22              T           NA            2336          2336
# 23              T           NA             879           879
# 24              C           NA             687           687
# 25              C           NA            1033          1033
# 26              C           NA            1158          1158
# 27              C           NA            1191          1191
# 28              C           NA            3049          3049
# 29              C           NA            3304          3304
# 30              A           NA            3342          3342
#
#                      keyword
# 0                        NaN
# 1         BRCA1 K50 missense
# 2       BRCA1 S1027 missense
# 3           BRCA1 truncating
# 4           BRCA1 truncating
# 5       BRCA1 D1344 missense
# 6         BRCA1 D96 missense
# 7     BRCA1 644-644 deletion
# 8          BRCA1 E9 missense
# 9       BRCA1 G1788 missense
# 10          BRCA1 truncating
# 11       BRCA1 D366 missense
# 12          BRCA1 truncating
# 13      BRCA1 E1419 missense
# 14      BRCA2 D1355 missense
# 15          BRCA2 truncating
# 16          BRCA2 truncating
# 17      BRCA2 E2175 missense
# 18      BRCA2 E2650 missense
# 19          BRCA2 truncating
# 20      BRCA2 E3177 missense
# 21  BRCA2 1270-1270 deletion
# 22      BRCA2 R2336 missense
# 23       BRCA2 S879 missense
# 24       BRCA2 D687 missense
# 25      BRCA2 D1033 missense
# 26      BRCA2 E1158 missense
# 27      BRCA2 K1191 missense
# 28      BRCA2 Y3049 missense
# 29      BRCA2 C3304 missense
# 30      BRCA2 E3342 missense
#
# [31 rows x 27 columns]

# %%
df3b = mts.fetch_muts_in_multiple_mol_profs(entrez_gene_ids=["672","675"], 
                                            sample_molecular_identifiers=[
                                                        {"molecular_profile_id": "brca_tcga_mutations", 
                                                         "sample_ids": ["TCGA-A2-A4S0-01","TCGA-E2-A1L9-01"]},
                                                        {"molecular_profile_id": "acc_tcga_mutations", 
                                                         "sample_ids": ["TCGA-OR-A5LE-01"]}
                                                        ])
df3b
# Out:
#                       uniqueSampleKey                uniquePatientKey  \
# 0    VENHQS1PUi1BNUxFLTAxOmFjY190Y2dh    VENHQS1PUi1BNUxFOmFjY190Y2dh
# 1  VENHQS1FMi1BMUw5LTAxOmJyY2FfdGNnYQ  VENHQS1FMi1BMUw5OmJyY2FfdGNnYQ
# 2  VENHQS1BMi1BNFMwLTAxOmJyY2FfdGNnYQ  VENHQS1BMi1BNFMwOmJyY2FfdGNnYQ
#
#     molecularProfileId         sampleId     patientId  entrezGeneId  \
# 0   acc_tcga_mutations  TCGA-OR-A5LE-01  TCGA-OR-A5LE           675
# 1  brca_tcga_mutations  TCGA-E2-A1L9-01  TCGA-E2-A1L9           672
# 2  brca_tcga_mutations  TCGA-A2-A4S0-01  TCGA-A2-A4S0           672
#
#      studyId            center mutationStatus validationStatus  ...  \
# 0   acc_tcga          bcgsc.ca        Somatic         Untested  ...
# 1  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
# 2  brca_tcga  genome.wustl.edu        Somatic         Untested  ...
#
#      proteinChange       mutationType  ncbiBuild  variantType  chr  \
# 0  V733_L734insFFF       In_Frame_Ins     GRCh37          INS   13
# 1           S1027I  Missense_Mutation     GRCh37          SNP   17
# 2             K50T  Missense_Mutation     GRCh37          SNP   17
#
#    variantAllele refseqMrnaId proteinPosStart proteinPosEnd  \
# 0      TCTTCTTCT           NA             733           734
# 1              A  NM_007294.3            1027          1027
# 2              G  NM_007294.3              50            50
#
#                 keyword
# 0                   NaN
# 1  BRCA1 S1027 missense
# 2    BRCA1 K50 missense
#
# [3 rows x 27 columns]
